# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/Face_Emotion_Recognition/archive.zip

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_dir = "/content/train"
test_dir = "/content/test"

# %%
train_datagen = ImageDataGenerator(
    width_shift_range = 0.1,        # Randomly shift the width of images by up to 10%
    height_shift_range = 0.1,       # Randomly shift the height of images by up to 10%
    horizontal_flip = True,         # Flip images horizontally at random
    rescale = 1./255,               # Rescale pixel values to be between 0 and 1
    validation_split = 0.2          # Set aside 20% of the data for validation
)

validation_datagen = ImageDataGenerator(
    rescale = 1./255,               # Rescale pixel values to be between 0 and 1
    validation_split = 0.2          # Set aside 20% of the data for validation
)

# %%
train_generator = train_datagen.flow_from_directory(
    directory = train_dir,           # Directory containing the training data
    target_size = (48, 48),          # Resizes all images to 48x48 pixels
    batch_size = 128,                 # Number of images per batch
    color_mode = "grayscale",        # Converts the images to grayscale
    class_mode = "categorical",      # Classifies the images into 7 categories
    subset = "training"              # Uses the training subset of the data
)

validation_generator = validation_datagen.flow_from_directory(
    directory = test_dir,            # Directory containing the validation data
    target_size = (48, 48),          # Resizes all images to 48x48 pixels
    batch_size = 128,                 # Number of images per batch
    color_mode = "grayscale",        # Converts the images to grayscale
    class_mode = "categorical",      # Classifies the images into 7 categories
    subset = "validation"            # Uses the validation subset of the data
)
# Out:
# Found 22968 images belonging to 7 classes.
# Found 1432 images belonging to 7 classes.

# %%
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.models import Sequential
import tensorflow as tf
from tensorflow.keras.layers import BatchNormalization

# Define the model architecture
model = Sequential()

# Add a convolutional layer with 32 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48,48,1)))
# Add a batch normalization layer
model.add(BatchNormalization())
# Add a second convolutional layer with 64 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
# Add a second batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Add a third convolutional layer with 128 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Add a third batch normalization layer
model.add(BatchNormalization())
# Add a fourth convolutional layer with 128 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Add a fourth batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Add a fifth convolutional layer with 256 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
# Add a fifth batch normalization layer
model.add(BatchNormalization())
# Add a sixth convolutional layer with 256 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
# Add a sixth batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Flatten the output of the convolutional layers
model.add(Flatten())
# Add a dense layer with 256 neurons and relu activation function
model.add(Dense(256, activation='relu'))
# Add a seventh batch normalization layer
model.add(BatchNormalization())
# Add a dropout layer with 0.5 dropout rate
model.add(Dropout(0.5))
# Add a dense layer with 7 neurons (one for each class) and softmax activation function
model.add(Dense(7, activation='softmax'))

# Compile the model with categorical cross-entropy loss, adam optimizer, and accuracy metric
model.compile(loss="categorical_crossentropy", optimizer= tf.keras.optimizers.Adam(learning_rate=0.0001), metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the callback
checkpoint_callback = ModelCheckpoint(
    filepath='model_weights.h5',
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=True,
    mode='max',
    verbose=1
)

# Train the model with the callback
history = model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=100,
    validation_data=validation_generator,
    validation_steps=len(validation_generator),
    callbacks=[checkpoint_callback]
)
# Out:
# Epoch 1/100
# 717/718 [============================>.] - ETA: 0s - loss: 2.3764 - accuracy: 0.2303
# Epoch 1: val_accuracy improved from -inf to 0.36662, saving model to model_weights.h5
# 718/718 [==============================] - 26s 36ms/step - loss: 2.3763 - accuracy: 0.2305 - val_loss: 1.6841 - val_accuracy: 0.3666
# Epoch 2/100
# 717/718 [============================>.] - ETA: 0s - loss: 2.1266 - accuracy: 0.2739
# Epoch 2: val_accuracy improved from 0.36662 to 0.38478, saving model to model_weights.h5
# 718/718 [==============================] - 27s 37ms/step - loss: 2.1261 - accuracy: 0.2740 - val_loss: 1.6369 - val_accuracy: 0.3848
# Epoch 3/100
# 718/718 [==============================] - ETA: 0s - loss: 1.9754 - accuracy: 0.3107
# Epoch 3: val_accuracy improved from 0.38478 to 0.41201, saving model to model_weights.h5
# 718/718 [==============================] - 24s 34ms/step - loss: 1.9754 - accuracy: 0.3107 - val_loss: 1.5443 - val_accuracy: 0.4120
# Epoch 4/100
# 718/718 [==============================] - ETA: 0s - loss: 1.8575 - accuracy: 0.3366
# Epoch 4: val_accuracy improved from 0.41201 to 0.43925, saving model to model_weights.h5
# 718/718 [==============================] - 26s 36ms/step - loss: 1.8575 - accuracy: 0.3366 - val_loss: 1.4969 - val_accuracy: 0.4392
# Epoch 5/100
# 717/718 [============================>.] - ETA: 0s - loss: 1.7461 - accuracy: 0.3589
# Epoch 5: val_accuracy improved from 0.43925 to 0.47975, saving model to model_weights.h5
# 718/718 [==============================] - 25s 35ms/step - loss: 1.7459 - accuracy: 0.3588 - val_loss: 1.3962 - val_accuracy: 0.4797
# Epoch 6/100
# 718/718 [==============================] - ETA: 0s - loss: 1.6622 - accuracy: 0.3844
# Epoch 6: val_accuracy improved from 0.47975 to 0.49232, saving model to model_weights.h5
# 718/718 [==============================] - 25s 35ms/step - loss: 1.6622 - accuracy: 0.3844 - val_loss: 1.3440 - val_accuracy: 0.4923
# Epoch 7/100
# 717/718 [============================>.] - ETA: 0s - loss: 1.5877 - accuracy: 0.4067
# Epoch 7: val_accuracy improved from 0.49232 to 0.50978, saving model to model_weights.h5
# 718/718 [==============================] - 27s 38ms/step - loss: 1.5873 - accuracy: 0.4070 - val_loss: 1.3120 - val_accuracy: 0.5098
# Epoch 8/100
# 717/718 [============================>.] - ETA: 0s - loss: 1.5217 - accuracy: 0.4304
# Epoch 8: val_accuracy improved from 0.50978 to 0.52304, saving model to model_weights.h5
# 718/718 [==============================] - 25s 35ms/step - loss: 1.5215 - accuracy: 0.4304 - val_loss: 1.2834 - val_accuracy: 0.5230
# Epoch 9/100
# 718/718 [==============================] - ETA: 0s - loss: 1.4588 - accuracy: 0.4442
# Epoch 9: val_accuracy improved from 0.52304 to 0.53492, saving model to model_weights.h5
# 718/718 [==============================] - 26s 36ms/step - loss: 1.4588 - accuracy: 0.4442 - val_loss: 1.2468 - val_accuracy: 0.5349
# Epoch 10/100
# 717/718 [============================>.] - ETA: 0s - loss: 1.4104 - accuracy: 0.4606
# Epoch 10: val_accuracy improved from 0.53492 to 0.57053, saving model to model_weights.h5
# 718/718 [==============================] - 25s 35ms/step - loss: 1.4102 - accuracy: 0.4609 - val_loss: 1.1864 - val_accuracy: 0.5705
# Epoch 11/100
# 717/718 [============================>.] - ETA: 0s - loss: 1.3696 - accuracy: 0.4804
# Epoch 11: val_accuracy did not improve from 0.57053
# 718/718 [==============================] - 25s 35ms/step - loss: 1.3698 - accuracy: 0.4803 - val_loss: 1.2018 - val_accuracy: 0.5440
# Epoch 12/100
# 717/718 [============================>.] - ETA: 0s - loss: 1.3346 - accuracy: 0.4928
# Epoch 12: val_accuracy did not improve from 0.57053
# 718/718 [==============================] - 27s 37ms/step - loss: 1.3340 - accuracy: 0.4931 - val_loss: 1.1931 - val_accuracy: 0.5552
# Epoch 13/100
# 718/718 [==============================] - ETA: 0s - loss: 1.3059 - accuracy: 0.5042
# Epoch 13: val_accuracy did not improve from 0.57053
# 718/718 [==============================] - 25s 35ms/step - loss: 1.3059 - accuracy: 0.5042 - val_loss: 1.1775 - val_accuracy: 0.5566
# Epoch 14/100
# 717/718 [============================>.] - ETA: 0s - loss: 1.2742 - accuracy: 0.5155
# Epoch 14: val_accuracy improved from 0.57053 to 0.58659, saving model to model_weights.h5
# 718/718 [==============================] - 25s 35ms/step - loss: 1.2741 - accuracy: 0.5155 - val_loss: 1.1186 - val_accuracy: 0.5866
# Epoch 15/100
# 717/718 [============================>.] - ETA: 0s - loss: 1.2530 - accuracy: 0.5261
# Epoch 15: val_accuracy improved from 0.58659 to 0.59008, saving model to model_weights.h5
# 718/718 [==============================] - 26s 36ms/step - loss: 1.2532 - accuracy: 0.5261 - val_loss: 1.1046 - val_accuracy: 0.5901
# Epoch 16/100
# 717/718 [============================>.] - ETA: 0s - loss: 1.2349 - accuracy: 0.5327
# Epoch 16: val_accuracy did not improve from 0.59008
# 718/718 [==============================] - 26s 36ms/step - loss: 1.2344 - accuracy: 0.5329 - val_loss: 1.0850 - val_accuracy: 0.5894
# Epoch 17/100
# 717/718 [============================>.] - ETA: 0s - loss: 1.2146 - accuracy: 0.5449
# Epoch 17: val_accuracy improved from 0.59008 to 0.59288, saving model to model_weights.h5
# 718/718 [==============================] - 26s 36ms/step - loss: 1.2147 - accuracy: 0.5448 - val_loss: 1.1114 - val_accuracy: 0.5929
# Epoch 18/100
# 717/718 [============================>.] - ETA: 0s - loss: 1.1902 - accuracy: 0.5539
# Epoch 18: val_accuracy improved from 0.59288 to 0.59497, saving model to model_weights.h5
# 718/718 [==============================] - 25s 35ms/step - loss: 1.1899 - accuracy: 0.5541 - val_loss: 1.0764 - val_accuracy: 0.5950
# Epoch 19/100
# 718/718 [==============================] - ETA: 0s - loss: 1.1726 - accuracy: 0.5559
# Epoch 19: val_accuracy improved from 0.59497 to 0.60196, saving model to model_weights.h5
# 718/718 [==============================] - 28s 38ms/step - loss: 1.1726 - accuracy: 0.5559 - val_loss: 1.0694 - val_accuracy: 0.6020
# Epoch 20/100
# 718/718 [==============================] - ETA: 0s - loss: 1.1613 - accuracy: 0.5599
# Epoch 20: val_accuracy improved from 0.60196 to 0.60894, saving model to model_weights.h5
# 718/718 [==============================] - 25s 35ms/step - loss: 1.1613 - accuracy: 0.5599 - val_loss: 1.0467 - val_accuracy: 0.6089
# Epoch 21/100
# 717/718 [============================>.] - ETA: 0s - loss: 1.1475 - accuracy: 0.5694
# Epoch 21: val_accuracy did not improve from 0.60894
# 718/718 [==============================] - 24s 34ms/step - loss: 1.1476 - accuracy: 0.5695 - val_loss: 1.0550 - val_accuracy: 0.6047
# Epoch 22/100
# 717/718 [============================>.] - ETA: 0s - loss: 1.1356 - accuracy: 0.5729
# Epoch 22: val_accuracy improved from 0.60894 to 0.61034, saving model to model_weights.h5
# 718/718 [==============================] - 26s 36ms/step - loss: 1.1360 - accuracy: 0.5728 - val_loss: 1.0446 - val_accuracy: 0.6103
# Epoch 23/100
# 717/718 [============================>.] - ETA: 0s - loss: 1.1296 - accuracy: 0.5756
# Epoch 23: val_accuracy improved from 0.61034 to 0.62430, saving model to model_weights.h5
# 718/718 [==============================] - 26s 36ms/step - loss: 1.1297 - accuracy: 0.5755 - val_loss: 1.0170 - val_accuracy: 0.6243
# Epoch 24/100
# 717/718 [============================>.] - ETA: 0s - loss: 1.1041 - accuracy: 0.5855
# Epoch 24: val_accuracy improved from 0.62430 to 0.63338, saving model to model_weights.h5
# 718/718 [==============================] - 27s 38ms/step - loss: 1.1045 - accuracy: 0.5855 - val_loss: 0.9971 - val_accuracy: 0.6334
# Epoch 25/100
# 717/718 [============================>.] - ETA: 0s - loss: 1.0978 - accuracy: 0.5863
# Epoch 25: val_accuracy did not improve from 0.63338
# 718/718 [==============================] - 26s 36ms/step - loss: 1.0980 - accuracy: 0.5863 - val_loss: 1.0117 - val_accuracy: 0.6173
# Epoch 26/100
# 718/718 [==============================] - ETA: 0s - loss: 1.0924 - accuracy: 0.5884
# Epoch 26: val_accuracy improved from 0.63338 to 0.64176, saving model to model_weights.h5
# 718/718 [==============================] - 26s 36ms/step - loss: 1.0924 - accuracy: 0.5884 - val_loss: 0.9816 - val_accuracy: 0.6418
# Epoch 27/100
# 717/718 [============================>.] - ETA: 0s - loss: 1.0754 - accuracy: 0.5975
# Epoch 27: val_accuracy did not improve from 0.64176
# 718/718 [==============================] - 25s 35ms/step - loss: 1.0756 - accuracy: 0.5975 - val_loss: 1.0196 - val_accuracy: 0.6236
# Epoch 28/100
# 718/718 [==============================] - ETA: 0s - loss: 1.0680 - accuracy: 0.5995
# Epoch 28: val_accuracy did not improve from 0.64176
# 718/718 [==============================] - 25s 35ms/step - loss: 1.0680 - accuracy: 0.5995 - val_loss: 1.0061 - val_accuracy: 0.6299
# Epoch 29/100
# 717/718 [============================>.] - ETA: 0s - loss: 1.0579 - accuracy: 0.6064
# Epoch 29: val_accuracy did not improve from 0.64176
# 718/718 [==============================] - 26s 36ms/step - loss: 1.0579 - accuracy: 0.6065 - val_loss: 0.9797 - val_accuracy: 0.6362
# Epoch 30/100
# 717/718 [============================>.] - ETA: 0s - loss: 1.0492 - accuracy: 0.6072
# Epoch 30: val_accuracy improved from 0.64176 to 0.65223, saving model to model_weights.h5
# 718/718 [==============================] - 26s 36ms/step - loss: 1.0490 - accuracy: 0.6073 - val_loss: 0.9514 - val_accuracy: 0.6522
# Epoch 31/100
# 718/718 [==============================] - ETA: 0s - loss: 1.0360 - accuracy: 0.6129
# Epoch 31: val_accuracy did not improve from 0.65223
# 718/718 [==============================] - 26s 36ms/step - loss: 1.0360 - accuracy: 0.6129 - val_loss: 0.9728 - val_accuracy: 0.6397
# Epoch 32/100
# 717/718 [============================>.] - ETA: 0s - loss: 1.0301 - accuracy: 0.6161
# Epoch 32: val_accuracy did not improve from 0.65223
# 718/718 [==============================] - 26s 36ms/step - loss: 1.0300 - accuracy: 0.6162 - val_loss: 0.9990 - val_accuracy: 0.6446
# Epoch 33/100
# 717/718 [============================>.] - ETA: 0s - loss: 1.0194 - accuracy: 0.6183
# Epoch 33: val_accuracy did not improve from 0.65223
# 718/718 [==============================] - 26s 36ms/step - loss: 1.0195 - accuracy: 0.6182 - val_loss: 0.9657 - val_accuracy: 0.6508
# Epoch 34/100
# 717/718 [============================>.] - ETA: 0s - loss: 1.0191 - accuracy: 0.6223
# Epoch 34: val_accuracy did not improve from 0.65223
# 718/718 [==============================] - 25s 35ms/step - loss: 1.0187 - accuracy: 0.6225 - val_loss: 0.9556 - val_accuracy: 0.6494
# Epoch 35/100
# 718/718 [==============================] - ETA: 0s - loss: 1.0065 - accuracy: 0.6232
# Epoch 35: val_accuracy did not improve from 0.65223
# 718/718 [==============================] - 26s 36ms/step - loss: 1.0065 - accuracy: 0.6232 - val_loss: 0.9469 - val_accuracy: 0.6480
# Epoch 36/100
# 717/718 [============================>.] - ETA: 0s - loss: 0.9984 - accuracy: 0.6265
# Epoch 36: val_accuracy improved from 0.65223 to 0.65433, saving model to model_weights.h5
# 718/718 [==============================] - 25s 35ms/step - loss: 0.9990 - accuracy: 0.6261 - val_loss: 0.9711 - val_accuracy: 0.6543
# Epoch 37/100
# 718/718 [==============================] - ETA: 0s - loss: 0.9864 - accuracy: 0.6331
# Epoch 37: val_accuracy did not improve from 0.65433
# 718/718 [==============================] - 26s 36ms/step - loss: 0.9864 - accuracy: 0.6331 - val_loss: 0.9477 - val_accuracy: 0.6494
# Epoch 38/100
# 718/718 [==============================] - ETA: 0s - loss: 0.9795 - accuracy: 0.6345
# Epoch 38: val_accuracy did not improve from 0.65433
# 718/718 [==============================] - 26s 36ms/step - loss: 0.9795 - accuracy: 0.6345 - val_loss: 0.9652 - val_accuracy: 0.6466
# Epoch 39/100
# 718/718 [==============================] - ETA: 0s - loss: 0.9784 - accuracy: 0.6345
# Epoch 39: val_accuracy did not improve from 0.65433
# 718/718 [==============================] - 26s 36ms/step - loss: 0.9784 - accuracy: 0.6345 - val_loss: 0.9588 - val_accuracy: 0.6501
# Epoch 40/100
# 718/718 [==============================] - ETA: 0s - loss: 0.9657 - accuracy: 0.6387
# Epoch 40: val_accuracy did not improve from 0.65433
# 718/718 [==============================] - 28s 39ms/step - loss: 0.9657 - accuracy: 0.6387 - val_loss: 0.9580 - val_accuracy: 0.6515
# Epoch 41/100
# 718/718 [==============================] - ETA: 0s - loss: 0.9690 - accuracy: 0.6410
# Epoch 41: val_accuracy did not improve from 0.65433
# 718/718 [==============================] - 25s 35ms/step - loss: 0.9690 - accuracy: 0.6410 - val_loss: 0.9428 - val_accuracy: 0.6529
# Epoch 42/100
# 718/718 [==============================] - ETA: 0s - loss: 0.9496 - accuracy: 0.6463
# Epoch 42: val_accuracy did not improve from 0.65433
# 718/718 [==============================] - 25s 35ms/step - loss: 0.9496 - accuracy: 0.6463 - val_loss: 0.9589 - val_accuracy: 0.6425
# Epoch 43/100
# 718/718 [==============================] - ETA: 0s - loss: 0.9393 - accuracy: 0.6486
# Epoch 43: val_accuracy improved from 0.65433 to 0.66061, saving model to model_weights.h5
# 718/718 [==============================] - 26s 36ms/step - loss: 0.9393 - accuracy: 0.6486 - val_loss: 0.9344 - val_accuracy: 0.6606
# Epoch 44/100
# 718/718 [==============================] - ETA: 0s - loss: 0.9359 - accuracy: 0.6527
# Epoch 44: val_accuracy did not improve from 0.66061
# 718/718 [==============================] - 26s 36ms/step - loss: 0.9359 - accuracy: 0.6527 - val_loss: 0.9533 - val_accuracy: 0.6487
# Epoch 45/100
# 717/718 [============================>.] - ETA: 0s - loss: 0.9363 - accuracy: 0.6468
# Epoch 45: val_accuracy did not improve from 0.66061
# 718/718 [==============================] - 26s 36ms/step - loss: 0.9366 - accuracy: 0.6466 - val_loss: 0.9585 - val_accuracy: 0.6543
# Epoch 46/100
# 717/718 [============================>.] - ETA: 0s - loss: 0.9270 - accuracy: 0.6550
# Epoch 46: val_accuracy did not improve from 0.66061
# 718/718 [==============================] - 28s 38ms/step - loss: 0.9271 - accuracy: 0.6550 - val_loss: 0.9425 - val_accuracy: 0.6592
# Epoch 47/100
# 717/718 [============================>.] - ETA: 0s - loss: 0.9259 - accuracy: 0.6524
# Epoch 47: val_accuracy did not improve from 0.66061
# 718/718 [==============================] - 25s 35ms/step - loss: 0.9259 - accuracy: 0.6524 - val_loss: 0.9481 - val_accuracy: 0.6557
# Epoch 48/100
# 718/718 [==============================] - ETA: 0s - loss: 0.9132 - accuracy: 0.6639
# Epoch 48: val_accuracy did not improve from 0.66061
# 718/718 [==============================] - 25s 35ms/step - loss: 0.9132 - accuracy: 0.6639 - val_loss: 0.9371 - val_accuracy: 0.6571
# Epoch 49/100
# 717/718 [============================>.] - ETA: 0s - loss: 0.9114 - accuracy: 0.6627
# Epoch 49: val_accuracy improved from 0.66061 to 0.66830, saving model to model_weights.h5
# 718/718 [==============================] - 26s 36ms/step - loss: 0.9113 - accuracy: 0.6626 - val_loss: 0.9298 - val_accuracy: 0.6683
# Epoch 50/100
# 717/718 [============================>.] - ETA: 0s - loss: 0.8986 - accuracy: 0.6672
# Epoch 50: val_accuracy did not improve from 0.66830
# 718/718 [==============================] - 26s 36ms/step - loss: 0.8987 - accuracy: 0.6673 - val_loss: 0.9353 - val_accuracy: 0.6634
# Epoch 51/100
# 717/718 [============================>.] - ETA: 0s - loss: 0.8976 - accuracy: 0.6665
# Epoch 51: val_accuracy did not improve from 0.66830
# 718/718 [==============================] - 26s 36ms/step - loss: 0.8975 - accuracy: 0.6667 - val_loss: 0.9133 - val_accuracy: 0.6662
# Epoch 52/100
# 718/718 [==============================] - ETA: 0s - loss: 0.8845 - accuracy: 0.6722
# Epoch 52: val_accuracy did not improve from 0.66830
# 718/718 [==============================] - 27s 38ms/step - loss: 0.8845 - accuracy: 0.6722 - val_loss: 0.9353 - val_accuracy: 0.6613
# Epoch 53/100
# 718/718 [==============================] - ETA: 0s - loss: 0.8724 - accuracy: 0.6762
# Epoch 53: val_accuracy did not improve from 0.66830
# 718/718 [==============================] - 25s 34ms/step - loss: 0.8724 - accuracy: 0.6762 - val_loss: 0.9260 - val_accuracy: 0.6592
# Epoch 54/100
# 718/718 [==============================] - ETA: 0s - loss: 0.8784 - accuracy: 0.6715
# Epoch 54: val_accuracy did not improve from 0.66830
# 718/718 [==============================] - 26s 36ms/step - loss: 0.8784 - accuracy: 0.6715 - val_loss: 0.9225 - val_accuracy: 0.6613
# Epoch 55/100
# 717/718 [============================>.] - ETA: 0s - loss: 0.8750 - accuracy: 0.6748
# Epoch 55: val_accuracy improved from 0.66830 to 0.67318, saving model to model_weights.h5
# 718/718 [==============================] - 26s 36ms/step - loss: 0.8749 - accuracy: 0.6749 - val_loss: 0.9222 - val_accuracy: 0.6732
# Epoch 56/100
# 718/718 [==============================] - ETA: 0s - loss: 0.8595 - accuracy: 0.6797
# Epoch 56: val_accuracy did not improve from 0.67318
# 718/718 [==============================] - 26s 36ms/step - loss: 0.8595 - accuracy: 0.6797 - val_loss: 0.9278 - val_accuracy: 0.6676
# Epoch 57/100
# 718/718 [==============================] - ETA: 0s - loss: 0.8650 - accuracy: 0.6779
# Epoch 57: val_accuracy did not improve from 0.67318
# 718/718 [==============================] - 26s 36ms/step - loss: 0.8650 - accuracy: 0.6779 - val_loss: 0.9110 - val_accuracy: 0.6697
# Epoch 58/100
# 717/718 [============================>.] - ETA: 0s - loss: 0.8539 - accuracy: 0.6797
# Epoch 58: val_accuracy improved from 0.67318 to 0.67668, saving model to model_weights.h5
# 718/718 [==============================] - 27s 38ms/step - loss: 0.8535 - accuracy: 0.6798 - val_loss: 0.8956 - val_accuracy: 0.6767
# Epoch 59/100
# 718/718 [==============================] - ETA: 0s - loss: 0.8443 - accuracy: 0.6838
# Epoch 59: val_accuracy did not improve from 0.67668
# 718/718 [==============================] - 26s 36ms/step - loss: 0.8443 - accuracy: 0.6838 - val_loss: 0.9188 - val_accuracy: 0.6718
# Epoch 60/100
# 718/718 [==============================] - ETA: 0s - loss: 0.8438 - accuracy: 0.6859
# Epoch 60: val_accuracy did not improve from 0.67668
# 718/718 [==============================] - 25s 35ms/step - loss: 0.8438 - accuracy: 0.6859 - val_loss: 0.9227 - val_accuracy: 0.6683
# Epoch 61/100
# 717/718 [============================>.] - ETA: 0s - loss: 0.8310 - accuracy: 0.6916
# Epoch 61: val_accuracy did not improve from 0.67668
# 718/718 [==============================] - 26s 36ms/step - loss: 0.8312 - accuracy: 0.6914 - val_loss: 0.9333 - val_accuracy: 0.6718
# Epoch 62/100
# 718/718 [==============================] - ETA: 0s - loss: 0.8301 - accuracy: 0.6925
# Epoch 62: val_accuracy did not improve from 0.67668
# 718/718 [==============================] - 26s 36ms/step - loss: 0.8301 - accuracy: 0.6925 - val_loss: 0.9504 - val_accuracy: 0.6480
# Epoch 63/100
# 717/718 [============================>.] - ETA: 0s - loss: 0.8261 - accuracy: 0.6955
# Epoch 63: val_accuracy did not improve from 0.67668
# 718/718 [==============================] - 26s 36ms/step - loss: 0.8260 - accuracy: 0.6955 - val_loss: 0.9596 - val_accuracy: 0.6557
# Epoch 64/100
# 718/718 [==============================] - ETA: 0s - loss: 0.8221 - accuracy: 0.6953
# Epoch 64: val_accuracy did not improve from 0.67668
# 718/718 [==============================] - 27s 38ms/step - loss: 0.8221 - accuracy: 0.6953 - val_loss: 0.9269 - val_accuracy: 0.6725
# Epoch 65/100
# 718/718 [==============================] - ETA: 0s - loss: 0.8114 - accuracy: 0.7008
# Epoch 65: val_accuracy did not improve from 0.67668
# 718/718 [==============================] - 26s 36ms/step - loss: 0.8114 - accuracy: 0.7008 - val_loss: 0.9352 - val_accuracy: 0.6690
# Epoch 66/100
# 717/718 [============================>.] - ETA: 0s - loss: 0.8161 - accuracy: 0.6989
# Epoch 66: val_accuracy improved from 0.67668 to 0.68087, saving model to model_weights.h5
# 718/718 [==============================] - 25s 35ms/step - loss: 0.8160 - accuracy: 0.6990 - val_loss: 0.9323 - val_accuracy: 0.6809
# Epoch 67/100
# 718/718 [==============================] - ETA: 0s - loss: 0.8058 - accuracy: 0.7025
# Epoch 67: val_accuracy did not improve from 0.68087
# 718/718 [==============================] - 25s 35ms/step - loss: 0.8058 - accuracy: 0.7025 - val_loss: 0.9367 - val_accuracy: 0.6634
# Epoch 68/100
# 717/718 [============================>.] - ETA: 0s - loss: 0.7967 - accuracy: 0.7042
# Epoch 68: val_accuracy did not improve from 0.68087
# 718/718 [==============================] - 26s 36ms/step - loss: 0.7968 - accuracy: 0.7041 - val_loss: 0.9476 - val_accuracy: 0.6767
# Epoch 69/100
# 718/718 [==============================] - ETA: 0s - loss: 0.8024 - accuracy: 0.7038
# Epoch 69: val_accuracy did not improve from 0.68087
# 718/718 [==============================] - 28s 38ms/step - loss: 0.8024 - accuracy: 0.7038 - val_loss: 0.9387 - val_accuracy: 0.6634
# Epoch 70/100
# 717/718 [============================>.] - ETA: 0s - loss: 0.7879 - accuracy: 0.7088
# Epoch 70: val_accuracy did not improve from 0.68087
# 718/718 [==============================] - 26s 36ms/step - loss: 0.7875 - accuracy: 0.7089 - val_loss: 0.9519 - val_accuracy: 0.6676
# Epoch 71/100
# 717/718 [============================>.] - ETA: 0s - loss: 0.7834 - accuracy: 0.7135
# Epoch 71: val_accuracy did not improve from 0.68087
# 718/718 [==============================] - 26s 36ms/step - loss: 0.7837 - accuracy: 0.7133 - val_loss: 0.9505 - val_accuracy: 0.6760
# Epoch 72/100
# 718/718 [==============================] - ETA: 0s - loss: 0.7808 - accuracy: 0.7089
# Epoch 72: val_accuracy did not improve from 0.68087
# 718/718 [==============================] - 26s 36ms/step - loss: 0.7808 - accuracy: 0.7089 - val_loss: 0.9565 - val_accuracy: 0.6592
# Epoch 73/100
# 717/718 [============================>.] - ETA: 0s - loss: 0.7738 - accuracy: 0.7136
# Epoch 73: val_accuracy did not improve from 0.68087
# 718/718 [==============================] - 26s 36ms/step - loss: 0.7737 - accuracy: 0.7135 - val_loss: 0.9283 - val_accuracy: 0.6725
# Epoch 74/100
# 717/718 [============================>.] - ETA: 0s - loss: 0.7740 - accuracy: 0.7112
# Epoch 74: val_accuracy did not improve from 0.68087
# 718/718 [==============================] - 27s 37ms/step - loss: 0.7739 - accuracy: 0.7113 - val_loss: 0.9301 - val_accuracy: 0.6739
# Epoch 75/100
# 717/718 [============================>.] - ETA: 0s - loss: 0.7632 - accuracy: 0.7149
# Epoch 75: val_accuracy did not improve from 0.68087
# 718/718 [==============================] - 26s 36ms/step - loss: 0.7636 - accuracy: 0.7147 - val_loss: 0.9551 - val_accuracy: 0.6669
# Epoch 76/100
# 718/718 [==============================] - ETA: 0s - loss: 0.7535 - accuracy: 0.7204
# Epoch 76: val_accuracy did not improve from 0.68087
# 718/718 [==============================] - 26s 36ms/step - loss: 0.7535 - accuracy: 0.7204 - val_loss: 0.9309 - val_accuracy: 0.6669
# Epoch 77/100
# 717/718 [============================>.] - ETA: 0s - loss: 0.7536 - accuracy: 0.7204
# Epoch 77: val_accuracy did not improve from 0.68087
# 718/718 [==============================] - 26s 36ms/step - loss: 0.7537 - accuracy: 0.7204 - val_loss: 0.9358 - val_accuracy: 0.6767
# Epoch 78/100
# 718/718 [==============================] - ETA: 0s - loss: 0.7442 - accuracy: 0.7257
# Epoch 78: val_accuracy did not improve from 0.68087
# 718/718 [==============================] - 26s 36ms/step - loss: 0.7442 - accuracy: 0.7257 - val_loss: 0.9218 - val_accuracy: 0.6760
# Epoch 79/100
# 718/718 [==============================] - ETA: 0s - loss: 0.7412 - accuracy: 0.7236
# Epoch 79: val_accuracy did not improve from 0.68087
# 718/718 [==============================] - 26s 36ms/step - loss: 0.7412 - accuracy: 0.7236 - val_loss: 0.9339 - val_accuracy: 0.6753
# Epoch 80/100
# 717/718 [============================>.] - ETA: 0s - loss: 0.7422 - accuracy: 0.7262
# Epoch 80: val_accuracy improved from 0.68087 to 0.68645, saving model to model_weights.h5
# 718/718 [==============================] - 28s 39ms/step - loss: 0.7422 - accuracy: 0.7263 - val_loss: 0.9384 - val_accuracy: 0.6865
# Epoch 81/100
# 718/718 [==============================] - ETA: 0s - loss: 0.7443 - accuracy: 0.7276
# Epoch 81: val_accuracy did not improve from 0.68645
# 718/718 [==============================] - 25s 35ms/step - loss: 0.7443 - accuracy: 0.7276 - val_loss: 0.9244 - val_accuracy: 0.6767
# Epoch 82/100
# 717/718 [============================>.] - ETA: 0s - loss: 0.7359 - accuracy: 0.7282
# Epoch 82: val_accuracy did not improve from 0.68645
# 718/718 [==============================] - 26s 36ms/step - loss: 0.7359 - accuracy: 0.7281 - val_loss: 0.9312 - val_accuracy: 0.6830
# Epoch 83/100
# 718/718 [==============================] - ETA: 0s - loss: 0.7266 - accuracy: 0.7320
# Epoch 83: val_accuracy did not improve from 0.68645
# 718/718 [==============================] - 26s 36ms/step - loss: 0.7266 - accuracy: 0.7320 - val_loss: 0.9364 - val_accuracy: 0.6858
# Epoch 84/100
# 718/718 [==============================] - ETA: 0s - loss: 0.7226 - accuracy: 0.7325
# Epoch 84: val_accuracy did not improve from 0.68645
# 718/718 [==============================] - 28s 39ms/step - loss: 0.7226 - accuracy: 0.7325 - val_loss: 0.9201 - val_accuracy: 0.6753
# Epoch 85/100
# 718/718 [==============================] - ETA: 0s - loss: 0.7154 - accuracy: 0.7344
# Epoch 85: val_accuracy did not improve from 0.68645
# 718/718 [==============================] - 26s 37ms/step - loss: 0.7154 - accuracy: 0.7344 - val_loss: 0.9315 - val_accuracy: 0.6711
# Epoch 86/100
# 717/718 [============================>.] - ETA: 0s - loss: 0.7130 - accuracy: 0.7343
# Epoch 86: val_accuracy did not improve from 0.68645
# 718/718 [==============================] - 27s 37ms/step - loss: 0.7129 - accuracy: 0.7343 - val_loss: 0.9398 - val_accuracy: 0.6802
# Epoch 87/100
# 717/718 [============================>.] - ETA: 0s - loss: 0.7114 - accuracy: 0.7383
# Epoch 87: val_accuracy did not improve from 0.68645
# 718/718 [==============================] - 26s 36ms/step - loss: 0.7112 - accuracy: 0.7383 - val_loss: 0.9593 - val_accuracy: 0.6662
# Epoch 88/100
# 717/718 [============================>.] - ETA: 0s - loss: 0.7089 - accuracy: 0.7414
# Epoch 88: val_accuracy did not improve from 0.68645
# 718/718 [==============================] - 26s 36ms/step - loss: 0.7087 - accuracy: 0.7414 - val_loss: 0.9474 - val_accuracy: 0.6837
# Epoch 89/100
# 718/718 [==============================] - ETA: 0s - loss: 0.6997 - accuracy: 0.7422
# Epoch 89: val_accuracy did not improve from 0.68645
# 718/718 [==============================] - 26s 36ms/step - loss: 0.6997 - accuracy: 0.7422 - val_loss: 0.9756 - val_accuracy: 0.6697
# Epoch 90/100
# 718/718 [==============================] - ETA: 0s - loss: 0.7005 - accuracy: 0.7425
# Epoch 90: val_accuracy did not improve from 0.68645
# 718/718 [==============================] - 26s 36ms/step - loss: 0.7005 - accuracy: 0.7425 - val_loss: 0.9375 - val_accuracy: 0.6746
# Epoch 91/100
# 717/718 [============================>.] - ETA: 0s - loss: 0.6872 - accuracy: 0.7456
# Epoch 91: val_accuracy did not improve from 0.68645
# 718/718 [==============================] - 25s 35ms/step - loss: 0.6872 - accuracy: 0.7455 - val_loss: 0.9333 - val_accuracy: 0.6788
# Epoch 92/100
# 717/718 [============================>.] - ETA: 0s - loss: 0.6904 - accuracy: 0.7441
# Epoch 92: val_accuracy did not improve from 0.68645
# 718/718 [==============================] - 25s 35ms/step - loss: 0.6903 - accuracy: 0.7441 - val_loss: 0.9629 - val_accuracy: 0.6802
# Epoch 93/100
# 718/718 [==============================] - ETA: 0s - loss: 0.6870 - accuracy: 0.7481
# Epoch 93: val_accuracy did not improve from 0.68645
# 718/718 [==============================] - 25s 35ms/step - loss: 0.6870 - accuracy: 0.7481 - val_loss: 0.9570 - val_accuracy: 0.6851
# Epoch 94/100
# 717/718 [============================>.] - ETA: 0s - loss: 0.6778 - accuracy: 0.7511
# Epoch 94: val_accuracy did not improve from 0.68645
# 718/718 [==============================] - 28s 39ms/step - loss: 0.6779 - accuracy: 0.7511 - val_loss: 0.9680 - val_accuracy: 0.6837
# Epoch 95/100
# 718/718 [==============================] - ETA: 0s - loss: 0.6768 - accuracy: 0.7524
# Epoch 95: val_accuracy did not improve from 0.68645
# 718/718 [==============================] - 27s 37ms/step - loss: 0.6768 - accuracy: 0.7524 - val_loss: 0.9733 - val_accuracy: 0.6802
# Epoch 96/100
# 718/718 [==============================] - ETA: 0s - loss: 0.6770 - accuracy: 0.7514
# Epoch 96: val_accuracy improved from 0.68645 to 0.68715, saving model to model_weights.h5
# 718/718 [==============================] - 26s 37ms/step - loss: 0.6770 - accuracy: 0.7514 - val_loss: 0.9614 - val_accuracy: 0.6872
# Epoch 97/100
# 718/718 [==============================] - ETA: 0s - loss: 0.6666 - accuracy: 0.7540
# Epoch 97: val_accuracy improved from 0.68715 to 0.69413, saving model to model_weights.h5
# 718/718 [==============================] - 25s 35ms/step - loss: 0.6666 - accuracy: 0.7540 - val_loss: 0.9537 - val_accuracy: 0.6941
# Epoch 98/100
# 717/718 [============================>.] - ETA: 0s - loss: 0.6703 - accuracy: 0.7502
# Epoch 98: val_accuracy did not improve from 0.69413
# 718/718 [==============================] - 26s 36ms/step - loss: 0.6702 - accuracy: 0.7502 - val_loss: 0.9621 - val_accuracy: 0.6865
# Epoch 99/100
# 718/718 [==============================] - ETA: 0s - loss: 0.6577 - accuracy: 0.7557
# Epoch 99: val_accuracy did not improve from 0.69413
# 718/718 [==============================] - 26s 37ms/step - loss: 0.6577 - accuracy: 0.7557 - val_loss: 0.9430 - val_accuracy: 0.6865
# Epoch 100/100
# 718/718 [==============================] - ETA: 0s - loss: 0.6595 - accuracy: 0.7545
# Epoch 100: val_accuracy did not improve from 0.69413
# 718/718 [==============================] - 28s 39ms/step - loss: 0.6595 - accuracy: 0.7545 - val_loss: 0.9421 - val_accuracy: 0.6781

# %%
# Plot the train and validation loss
from matplotlib import pyplot as plt

train_loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(train_loss) + 1)
plt.plot(epochs, train_loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np

# Get the true labels and predicted labels for the validation set
validation_labels = validation_generator.classes
validation_pred_probs = model.predict(validation_generator)
validation_pred_labels = np.argmax(validation_pred_probs, axis=1)

# Compute the confusion matrix
confusion_mtx = confusion_matrix(validation_labels, validation_pred_labels)
class_names = list(train_generator.class_indices.keys())
sns.set()
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='YlGnBu',
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 45/45 [==============================] - 1s 12ms/step

# %%
print(classification_report(validation_labels, validation_pred_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.13      0.13      0.13       191
#            1       0.08      0.05      0.06        22
#            2       0.13      0.12      0.12       204
#            3       0.24      0.23      0.24       354
#            4       0.17      0.23      0.20       246
#            5       0.20      0.17      0.18       249
#            6       0.12      0.13      0.12       166
#
#     accuracy                           0.18      1432
#    macro avg       0.15      0.15      0.15      1432
# weighted avg       0.17      0.18      0.17      1432
