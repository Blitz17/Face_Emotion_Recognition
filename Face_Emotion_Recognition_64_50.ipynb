# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/Face_Emotion_Recognition/archive.zip

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_dir = "/content/train"
test_dir = "/content/test"

# %%
train_datagen = ImageDataGenerator(
    width_shift_range = 0.1,        # Randomly shift the width of images by up to 10%
    height_shift_range = 0.1,       # Randomly shift the height of images by up to 10%
    horizontal_flip = True,         # Flip images horizontally at random
    rescale = 1./255,               # Rescale pixel values to be between 0 and 1
    validation_split = 0.2          # Set aside 20% of the data for validation
)

validation_datagen = ImageDataGenerator(
    rescale = 1./255,               # Rescale pixel values to be between 0 and 1
    validation_split = 0.2          # Set aside 20% of the data for validation
)

# %%
train_generator = train_datagen.flow_from_directory(
    directory = train_dir,           # Directory containing the training data
    target_size = (48, 48),          # Resizes all images to 48x48 pixels
    batch_size = 64,                 # Number of images per batch
    color_mode = "grayscale",        # Converts the images to grayscale
    class_mode = "categorical",      # Classifies the images into 7 categories
    subset = "training"              # Uses the training subset of the data
)

validation_generator = validation_datagen.flow_from_directory(
    directory = test_dir,            # Directory containing the validation data
    target_size = (48, 48),          # Resizes all images to 48x48 pixels
    batch_size = 64,                 # Number of images per batch
    color_mode = "grayscale",        # Converts the images to grayscale
    class_mode = "categorical",      # Classifies the images into 7 categories
    subset = "validation"            # Uses the validation subset of the data
)
# Out:
# Found 22968 images belonging to 7 classes.
# Found 1432 images belonging to 7 classes.

# %%
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.models import Sequential
import tensorflow as tf
from tensorflow.keras.layers import BatchNormalization

# Define the model architecture
model = Sequential()

# Add a convolutional layer with 32 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48,48,1)))
# Add a batch normalization layer
model.add(BatchNormalization())
# Add a second convolutional layer with 64 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
# Add a second batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Add a third convolutional layer with 128 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Add a third batch normalization layer
model.add(BatchNormalization())
# Add a fourth convolutional layer with 128 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Add a fourth batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Add a fifth convolutional layer with 256 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
# Add a fifth batch normalization layer
model.add(BatchNormalization())
# Add a sixth convolutional layer with 256 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
# Add a sixth batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Flatten the output of the convolutional layers
model.add(Flatten())
# Add a dense layer with 256 neurons and relu activation function
model.add(Dense(256, activation='relu'))
# Add a seventh batch normalization layer
model.add(BatchNormalization())
# Add a dropout layer with 0.5 dropout rate
model.add(Dropout(0.5))
# Add a dense layer with 7 neurons (one for each class) and softmax activation function
model.add(Dense(7, activation='softmax'))

# Compile the model with categorical cross-entropy loss, adam optimizer, and accuracy metric
model.compile(loss="categorical_crossentropy", optimizer= tf.keras.optimizers.Adam(learning_rate=0.0001), metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the callback
checkpoint_callback = ModelCheckpoint(
    filepath='model_weights.h5',
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=True,
    mode='max',
    verbose=1
)

# Train the model with the callback
history = model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=50,
    validation_data=validation_generator,
    validation_steps=len(validation_generator),
    callbacks=[checkpoint_callback]
)
# Out:
# Epoch 1/50
# 359/359 [==============================] - ETA: 0s - loss: 2.7884 - accuracy: 0.1863
# Epoch 1: val_accuracy improved from -inf to 0.17179, saving model to model_weights.h5
# 359/359 [==============================] - 46s 80ms/step - loss: 2.7884 - accuracy: 0.1863 - val_loss: 2.0378 - val_accuracy: 0.1718
# Epoch 2/50
# 359/359 [==============================] - ETA: 0s - loss: 2.4025 - accuracy: 0.2259
# Epoch 2: val_accuracy improved from 0.17179 to 0.34637, saving model to model_weights.h5
# 359/359 [==============================] - 24s 66ms/step - loss: 2.4025 - accuracy: 0.2259 - val_loss: 1.7388 - val_accuracy: 0.3464
# Epoch 3/50
# 359/359 [==============================] - ETA: 0s - loss: 2.1934 - accuracy: 0.2630
# Epoch 3: val_accuracy improved from 0.34637 to 0.35335, saving model to model_weights.h5
# 359/359 [==============================] - 24s 67ms/step - loss: 2.1934 - accuracy: 0.2630 - val_loss: 1.6783 - val_accuracy: 0.3534
# Epoch 4/50
# 359/359 [==============================] - ETA: 0s - loss: 2.0726 - accuracy: 0.2848
# Epoch 4: val_accuracy improved from 0.35335 to 0.38897, saving model to model_weights.h5
# 359/359 [==============================] - 23s 63ms/step - loss: 2.0726 - accuracy: 0.2848 - val_loss: 1.6001 - val_accuracy: 0.3890
# Epoch 5/50
# 359/359 [==============================] - ETA: 0s - loss: 1.9624 - accuracy: 0.3154
# Epoch 5: val_accuracy did not improve from 0.38897
# 359/359 [==============================] - 24s 65ms/step - loss: 1.9624 - accuracy: 0.3154 - val_loss: 1.6006 - val_accuracy: 0.3841
# Epoch 6/50
# 359/359 [==============================] - ETA: 0s - loss: 1.8736 - accuracy: 0.3322
# Epoch 6: val_accuracy improved from 0.38897 to 0.40223, saving model to model_weights.h5
# 359/359 [==============================] - 23s 64ms/step - loss: 1.8736 - accuracy: 0.3322 - val_loss: 1.5460 - val_accuracy: 0.4022
# Epoch 7/50
# 359/359 [==============================] - ETA: 0s - loss: 1.8108 - accuracy: 0.3497
# Epoch 7: val_accuracy improved from 0.40223 to 0.43925, saving model to model_weights.h5
# 359/359 [==============================] - 24s 66ms/step - loss: 1.8108 - accuracy: 0.3497 - val_loss: 1.4556 - val_accuracy: 0.4392
# Epoch 8/50
# 359/359 [==============================] - ETA: 0s - loss: 1.7522 - accuracy: 0.3662
# Epoch 8: val_accuracy improved from 0.43925 to 0.45461, saving model to model_weights.h5
# 359/359 [==============================] - 22s 62ms/step - loss: 1.7522 - accuracy: 0.3662 - val_loss: 1.4310 - val_accuracy: 0.4546
# Epoch 9/50
# 359/359 [==============================] - ETA: 0s - loss: 1.6771 - accuracy: 0.3861
# Epoch 9: val_accuracy improved from 0.45461 to 0.46299, saving model to model_weights.h5
# 359/359 [==============================] - 24s 66ms/step - loss: 1.6771 - accuracy: 0.3861 - val_loss: 1.3920 - val_accuracy: 0.4630
# Epoch 10/50
# 359/359 [==============================] - ETA: 0s - loss: 1.6272 - accuracy: 0.4002
# Epoch 10: val_accuracy improved from 0.46299 to 0.49860, saving model to model_weights.h5
# 359/359 [==============================] - 23s 64ms/step - loss: 1.6272 - accuracy: 0.4002 - val_loss: 1.3243 - val_accuracy: 0.4986
# Epoch 11/50
# 359/359 [==============================] - ETA: 0s - loss: 1.5767 - accuracy: 0.4174
# Epoch 11: val_accuracy improved from 0.49860 to 0.51466, saving model to model_weights.h5
# 359/359 [==============================] - 24s 66ms/step - loss: 1.5767 - accuracy: 0.4174 - val_loss: 1.3043 - val_accuracy: 0.5147
# Epoch 12/50
# 359/359 [==============================] - ETA: 0s - loss: 1.5229 - accuracy: 0.4340
# Epoch 12: val_accuracy did not improve from 0.51466
# 359/359 [==============================] - 25s 69ms/step - loss: 1.5229 - accuracy: 0.4340 - val_loss: 1.3151 - val_accuracy: 0.5147
# Epoch 13/50
# 359/359 [==============================] - ETA: 0s - loss: 1.4838 - accuracy: 0.4485
# Epoch 13: val_accuracy improved from 0.51466 to 0.52304, saving model to model_weights.h5
# 359/359 [==============================] - 22s 62ms/step - loss: 1.4838 - accuracy: 0.4485 - val_loss: 1.2607 - val_accuracy: 0.5230
# Epoch 14/50
# 359/359 [==============================] - ETA: 0s - loss: 1.4446 - accuracy: 0.4584
# Epoch 14: val_accuracy did not improve from 0.52304
# 359/359 [==============================] - 23s 65ms/step - loss: 1.4446 - accuracy: 0.4584 - val_loss: 1.2392 - val_accuracy: 0.5223
# Epoch 15/50
# 359/359 [==============================] - ETA: 0s - loss: 1.4093 - accuracy: 0.4723
# Epoch 15: val_accuracy improved from 0.52304 to 0.54260, saving model to model_weights.h5
# 359/359 [==============================] - 23s 64ms/step - loss: 1.4093 - accuracy: 0.4723 - val_loss: 1.2012 - val_accuracy: 0.5426
# Epoch 16/50
# 359/359 [==============================] - ETA: 0s - loss: 1.3795 - accuracy: 0.4776
# Epoch 16: val_accuracy improved from 0.54260 to 0.54958, saving model to model_weights.h5
# 359/359 [==============================] - 24s 67ms/step - loss: 1.3795 - accuracy: 0.4776 - val_loss: 1.2152 - val_accuracy: 0.5496
# Epoch 17/50
# 359/359 [==============================] - ETA: 0s - loss: 1.3473 - accuracy: 0.4927
# Epoch 17: val_accuracy improved from 0.54958 to 0.56494, saving model to model_weights.h5
# 359/359 [==============================] - 22s 61ms/step - loss: 1.3473 - accuracy: 0.4927 - val_loss: 1.1651 - val_accuracy: 0.5649
# Epoch 18/50
# 359/359 [==============================] - ETA: 0s - loss: 1.3222 - accuracy: 0.5048
# Epoch 18: val_accuracy improved from 0.56494 to 0.56774, saving model to model_weights.h5
# 359/359 [==============================] - 22s 62ms/step - loss: 1.3222 - accuracy: 0.5048 - val_loss: 1.1612 - val_accuracy: 0.5677
# Epoch 19/50
# 359/359 [==============================] - ETA: 0s - loss: 1.2995 - accuracy: 0.5127
# Epoch 19: val_accuracy improved from 0.56774 to 0.58101, saving model to model_weights.h5
# 359/359 [==============================] - 23s 64ms/step - loss: 1.2995 - accuracy: 0.5127 - val_loss: 1.1342 - val_accuracy: 0.5810
# Epoch 20/50
# 359/359 [==============================] - ETA: 0s - loss: 1.2778 - accuracy: 0.5186
# Epoch 20: val_accuracy did not improve from 0.58101
# 359/359 [==============================] - 24s 65ms/step - loss: 1.2778 - accuracy: 0.5186 - val_loss: 1.1477 - val_accuracy: 0.5677
# Epoch 21/50
# 359/359 [==============================] - ETA: 0s - loss: 1.2530 - accuracy: 0.5299
# Epoch 21: val_accuracy did not improve from 0.58101
# 359/359 [==============================] - 22s 61ms/step - loss: 1.2530 - accuracy: 0.5299 - val_loss: 1.1469 - val_accuracy: 0.5566
# Epoch 22/50
# 359/359 [==============================] - ETA: 0s - loss: 1.2400 - accuracy: 0.5328
# Epoch 22: val_accuracy did not improve from 0.58101
# 359/359 [==============================] - 25s 70ms/step - loss: 1.2400 - accuracy: 0.5328 - val_loss: 1.1028 - val_accuracy: 0.5803
# Epoch 23/50
# 359/359 [==============================] - ETA: 0s - loss: 1.2203 - accuracy: 0.5421
# Epoch 23: val_accuracy did not improve from 0.58101
# 359/359 [==============================] - 23s 65ms/step - loss: 1.2203 - accuracy: 0.5421 - val_loss: 1.1405 - val_accuracy: 0.5698
# Epoch 24/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1994 - accuracy: 0.5501
# Epoch 24: val_accuracy did not improve from 0.58101
# 359/359 [==============================] - 23s 65ms/step - loss: 1.1994 - accuracy: 0.5501 - val_loss: 1.1198 - val_accuracy: 0.5726
# Epoch 25/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1944 - accuracy: 0.5529
# Epoch 25: val_accuracy improved from 0.58101 to 0.60545, saving model to model_weights.h5
# 359/359 [==============================] - 24s 65ms/step - loss: 1.1944 - accuracy: 0.5529 - val_loss: 1.0651 - val_accuracy: 0.6054
# Epoch 26/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1849 - accuracy: 0.5536
# Epoch 26: val_accuracy did not improve from 0.60545
# 359/359 [==============================] - 22s 61ms/step - loss: 1.1849 - accuracy: 0.5536 - val_loss: 1.0572 - val_accuracy: 0.6041
# Epoch 27/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1696 - accuracy: 0.5600
# Epoch 27: val_accuracy did not improve from 0.60545
# 359/359 [==============================] - 22s 61ms/step - loss: 1.1696 - accuracy: 0.5600 - val_loss: 1.0706 - val_accuracy: 0.5978
# Epoch 28/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1534 - accuracy: 0.5681
# Epoch 28: val_accuracy did not improve from 0.60545
# 359/359 [==============================] - 24s 66ms/step - loss: 1.1534 - accuracy: 0.5681 - val_loss: 1.0915 - val_accuracy: 0.5859
# Epoch 29/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1378 - accuracy: 0.5743
# Epoch 29: val_accuracy did not improve from 0.60545
# 359/359 [==============================] - 24s 66ms/step - loss: 1.1378 - accuracy: 0.5743 - val_loss: 1.0660 - val_accuracy: 0.5943
# Epoch 30/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1322 - accuracy: 0.5751
# Epoch 30: val_accuracy did not improve from 0.60545
# 359/359 [==============================] - 23s 64ms/step - loss: 1.1322 - accuracy: 0.5751 - val_loss: 1.0506 - val_accuracy: 0.5964
# Epoch 31/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1169 - accuracy: 0.5869
# Epoch 31: val_accuracy did not improve from 0.60545
# 359/359 [==============================] - 25s 71ms/step - loss: 1.1169 - accuracy: 0.5869 - val_loss: 1.0676 - val_accuracy: 0.6020
# Epoch 32/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1115 - accuracy: 0.5839
# Epoch 32: val_accuracy improved from 0.60545 to 0.61522, saving model to model_weights.h5
# 359/359 [==============================] - 22s 61ms/step - loss: 1.1115 - accuracy: 0.5839 - val_loss: 1.0124 - val_accuracy: 0.6152
# Epoch 33/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1063 - accuracy: 0.5863
# Epoch 33: val_accuracy did not improve from 0.61522
# 359/359 [==============================] - 22s 62ms/step - loss: 1.1063 - accuracy: 0.5863 - val_loss: 1.0259 - val_accuracy: 0.6082
# Epoch 34/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0945 - accuracy: 0.5896
# Epoch 34: val_accuracy did not improve from 0.61522
# 359/359 [==============================] - 23s 64ms/step - loss: 1.0945 - accuracy: 0.5896 - val_loss: 1.0918 - val_accuracy: 0.5936
# Epoch 35/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0847 - accuracy: 0.5949
# Epoch 35: val_accuracy improved from 0.61522 to 0.62570, saving model to model_weights.h5
# 359/359 [==============================] - 24s 65ms/step - loss: 1.0847 - accuracy: 0.5949 - val_loss: 1.0059 - val_accuracy: 0.6257
# Epoch 36/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0793 - accuracy: 0.5955
# Epoch 36: val_accuracy did not improve from 0.62570
# 359/359 [==============================] - 35s 98ms/step - loss: 1.0793 - accuracy: 0.5955 - val_loss: 0.9929 - val_accuracy: 0.6215
# Epoch 37/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0660 - accuracy: 0.6017
# Epoch 37: val_accuracy did not improve from 0.62570
# 359/359 [==============================] - 23s 63ms/step - loss: 1.0660 - accuracy: 0.6017 - val_loss: 1.0227 - val_accuracy: 0.6034
# Epoch 38/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0644 - accuracy: 0.6024
# Epoch 38: val_accuracy did not improve from 0.62570
# 359/359 [==============================] - 24s 65ms/step - loss: 1.0644 - accuracy: 0.6024 - val_loss: 0.9994 - val_accuracy: 0.6243
# Epoch 39/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0446 - accuracy: 0.6071
# Epoch 39: val_accuracy improved from 0.62570 to 0.62709, saving model to model_weights.h5
# 359/359 [==============================] - 25s 70ms/step - loss: 1.0446 - accuracy: 0.6071 - val_loss: 0.9831 - val_accuracy: 0.6271
# Epoch 40/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0388 - accuracy: 0.6124
# Epoch 40: val_accuracy did not improve from 0.62709
# 359/359 [==============================] - 23s 65ms/step - loss: 1.0388 - accuracy: 0.6124 - val_loss: 0.9827 - val_accuracy: 0.6257
# Epoch 41/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0324 - accuracy: 0.6132
# Epoch 41: val_accuracy improved from 0.62709 to 0.62849, saving model to model_weights.h5
# 359/359 [==============================] - 22s 62ms/step - loss: 1.0324 - accuracy: 0.6132 - val_loss: 1.0059 - val_accuracy: 0.6285
# Epoch 42/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0274 - accuracy: 0.6172
# Epoch 42: val_accuracy did not improve from 0.62849
# 359/359 [==============================] - 25s 70ms/step - loss: 1.0274 - accuracy: 0.6172 - val_loss: 1.0284 - val_accuracy: 0.6201
# Epoch 43/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0207 - accuracy: 0.6173
# Epoch 43: val_accuracy improved from 0.62849 to 0.63478, saving model to model_weights.h5
# 359/359 [==============================] - 23s 65ms/step - loss: 1.0207 - accuracy: 0.6173 - val_loss: 0.9804 - val_accuracy: 0.6348
# Epoch 44/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0173 - accuracy: 0.6207
# Epoch 44: val_accuracy improved from 0.63478 to 0.64525, saving model to model_weights.h5
# 359/359 [==============================] - 22s 62ms/step - loss: 1.0173 - accuracy: 0.6207 - val_loss: 0.9729 - val_accuracy: 0.6453
# Epoch 45/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0073 - accuracy: 0.6224
# Epoch 45: val_accuracy improved from 0.64525 to 0.65223, saving model to model_weights.h5
# 359/359 [==============================] - 24s 66ms/step - loss: 1.0073 - accuracy: 0.6224 - val_loss: 0.9538 - val_accuracy: 0.6522
# Epoch 46/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0011 - accuracy: 0.6222
# Epoch 46: val_accuracy did not improve from 0.65223
# 359/359 [==============================] - 30s 85ms/step - loss: 1.0011 - accuracy: 0.6222 - val_loss: 0.9843 - val_accuracy: 0.6271
# Epoch 47/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9933 - accuracy: 0.6276
# Epoch 47: val_accuracy did not improve from 0.65223
# 359/359 [==============================] - 25s 70ms/step - loss: 0.9933 - accuracy: 0.6276 - val_loss: 0.9532 - val_accuracy: 0.6522
# Epoch 48/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9888 - accuracy: 0.6304
# Epoch 48: val_accuracy did not improve from 0.65223
# 359/359 [==============================] - 24s 66ms/step - loss: 0.9888 - accuracy: 0.6304 - val_loss: 0.9726 - val_accuracy: 0.6369
# Epoch 49/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9774 - accuracy: 0.6359
# Epoch 49: val_accuracy improved from 0.65223 to 0.65363, saving model to model_weights.h5
# 359/359 [==============================] - 23s 64ms/step - loss: 0.9774 - accuracy: 0.6359 - val_loss: 0.9474 - val_accuracy: 0.6536
# Epoch 50/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9705 - accuracy: 0.6374
# Epoch 50: val_accuracy did not improve from 0.65363
# 359/359 [==============================] - 22s 62ms/step - loss: 0.9705 - accuracy: 0.6374 - val_loss: 0.9532 - val_accuracy: 0.6390

# %%
# Plot the train and validation loss
from matplotlib import pyplot as plt

train_loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(train_loss) + 1)
plt.plot(epochs, train_loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np

# Get the true labels and predicted labels for the validation set
validation_labels = validation_generator.classes
validation_pred_probs = model.predict(validation_generator)
validation_pred_labels = np.argmax(validation_pred_probs, axis=1)

# Compute the confusion matrix
confusion_mtx = confusion_matrix(validation_labels, validation_pred_labels)
class_names = list(train_generator.class_indices.keys())
sns.set()
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='YlGnBu',
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 23/23 [==============================] - 0s 20ms/step

# %%
print(classification_report(validation_labels, validation_pred_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.12      0.12      0.12       191
#            1       0.00      0.00      0.00        22
#            2       0.12      0.09      0.10       204
#            3       0.23      0.24      0.24       354
#            4       0.13      0.15      0.14       246
#            5       0.19      0.20      0.20       249
#            6       0.15      0.13      0.14       166
#
#     accuracy                           0.17      1432
#    macro avg       0.13      0.13      0.13      1432
# weighted avg       0.16      0.17      0.16      1432
